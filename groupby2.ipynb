# %% [markdown]
# # Occupation

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')
users.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
def is_male(x):
    if x == 'M':
        return 1
    else:
        return 0
    
users['is_male'] = users['gender'].apply(is_male)

ratio = users.groupby('occupation').is_male.sum()/users.occupation.value_counts()

ratio.sort_values(ascending = False)
# Out:
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# dtype: float64

# %%
type(ratio)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby('occupation')['age'].agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(['occupation', 'gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
users.groupby('occupation').gender.value_counts(normalize=True)
# Out:
# occupation     gender
# administrator  M         0.544304
#                F         0.455696
# artist         M         0.535714
#                F         0.464286
# doctor         M         1.000000
# educator       M         0.726316
#                F         0.273684
# engineer       M         0.970149
#                F         0.029851
# entertainment  M         0.888889
#                F         0.111111
# executive      M         0.906250
#                F         0.093750
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         M         0.833333
#                F         0.166667
# librarian      F         0.568627
#                M         0.431373
# marketing      M         0.615385
#                F         0.384615
# none           M         0.555556
#                F         0.444444
# other          M         0.657143
#                F         0.342857
# ...

# %%
# create a data frame and apply count to gender
gender_ocup = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})

# create a DataFrame and apply count for each occupation
occup_count = users.groupby(['occupation']).agg('count')

# divide the gender_ocup per the occup_count and multiply per 100
#occup_gender = gender_ocup.div(occup_count, level = "occupation") * 100

# present all rows from the 'gender column'
#occup_gender.loc[: , 'gender']

# %%
users.groupby(['occupation', 'gender','age']).zip_code.max().unstack(level = 2)
# Out:
# age                      7      10     11     13     14     15     16     17  \
# occupation    gender
# administrator F         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#               M         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# artist        F         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#               M         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# doctor        M         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# educator      F         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#               M         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# engineer      F         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#               M         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# entertainment F         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#               M         NaN    NaN    NaN    NaN    NaN  20755    NaN  37777
# ...

# %%
users.groupby(['occupation', 'gender']).age.mean().unstack(level = 1)
# Out:
# gender                 F          M
# occupation
# administrator  40.638889  37.162791
# artist         30.307692  32.333333
# doctor               NaN  43.571429
# educator       39.115385  43.101449
# engineer       29.500000  36.600000
# entertainment  31.000000  29.000000
# executive      44.000000  38.172414
# healthcare     39.818182  45.400000
# homemaker      34.166667  23.000000
# lawyer         39.500000  36.200000
# librarian      40.000000  40.000000
# marketing      37.200000  37.875000
# none           36.500000  18.600000
# other          35.472222  34.028986
# programmer     32.166667  33.216667
# retired        70.000000  62.538462
# salesman       27.000000  38.555556
# scientist      28.333333  36.321429
# student        20.750000  22.669118
# technician     38.000000  32.961538
# writer         37.631579  35.346154

# %%
gender_ocup/occup_count
# Out:
#                       age    gender  is_male  zip_code
# occupation    gender
# administrator F       NaN  0.455696      NaN       NaN
#               M       NaN  0.544304      NaN       NaN
# artist        F       NaN  0.464286      NaN       NaN
#               M       NaN  0.535714      NaN       NaN
# doctor        M       NaN  1.000000      NaN       NaN
# educator      F       NaN  0.273684      NaN       NaN
#               M       NaN  0.726316      NaN       NaN
# engineer      F       NaN  0.029851      NaN       NaN
#               M       NaN  0.970149      NaN       NaN
# entertainment F       NaN  0.111111      NaN       NaN
#               M       NaN  0.888889      NaN       NaN
# executive     F       NaN  0.093750      NaN       NaN
#               M       NaN  0.906250      NaN       NaN
# healthcare    F       NaN  0.687500      NaN       NaN
#               M       NaN  0.312500      NaN       NaN
# homemaker     F       NaN  0.857143      NaN       NaN
# ...
